# %% [markdown]
# # Text Extraction
# - Reads the PDFs associated with FOMC, ECB, and BoE statements.
# - Outputs an excel file with three sheets: 'fomc', 'ecb', 'boe'.
# - Each sheet contains FK score, DC score, word count, text, lemmatized text.

# %%
import numpy as np
import pandas as pd
#import textract
#import pdfkit
import os
import PyPDF2
import re
import textstat
import spacy
from datetime import datetime
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl
import statistics
from IPython.core.display import display, HTML
import random
pd.set_option('display.max_rows', 10)
# Out:
# /var/folders/s6/xgx8wq8n63q742dx4hm1b4l00000gn/T/ipykernel_17412/3453400756.py:16: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# Flesch Kincaid Score
def calc_fk(text):
    return textstat.flesch_kincaid_grade(text)

# Dale Chall Score
def calc_dc(text):
    return textstat.dale_chall_readability_score(text)

# Extract 3 samples of size 200 from longer statements/minutes
def get_random_samples(text, num_samples=3, sample_size=200):
    words = text.split()  
    total_words = len(words)
    samples = []
    if total_words < sample_size:
        samples.append(text)
        samples.append(text)
        samples.append(text)
        return samples

    for _ in range(num_samples):
        start_idx = random.randint(0, total_words - sample_size)  # Pick a random start index
        sample = " ".join(words[start_idx:start_idx + sample_size])  # Extract 200 words
        samples.append(sample)
    
    return samples

# Function to "lemmatize" text using spacy, preparing for DC score calculation
def lemmatize_text(text):
    doc = nlp(text)
    words = []
    spaces = [token.whitespace_ for token in doc]
    for token, space in zip(doc, spaces):
        words.append(token.lemma_)
        if space:
            words.append(" ")
    return "".join(words)

# %%
# process pdfs, calculate their scores, given a text processing function - names are monetary, boe, ecb
def process_pdfs(folder_path, text_function, name, start, end):
    results = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdf') and name in filename:
            # Extract date from the filename
            
            date_str = filename[start:end]  
            date = datetime.strptime(date_str, '%Y%m%d')

            pdf_path = os.path.join(folder_path, filename)
            try:
                text = text_function(pdf_path)
                wc = len(text.split())
                # For longer PDFs, take random samples of the text
                samples = get_random_samples(text)
                fk_scores = []
                dc_scores = []
                lemmas = []

                for sample in samples:
                    fk_score = calc_fk(sample)
                    fk_scores.append(fk_score)
                    lemma = lemmatize_text(sample)
                    lemmas.append(lemma)
                    dc_score = calc_dc(lemma)
                    dc_scores.append(dc_score)

                fk_score = statistics.mean(fk_scores)
                dc_score = statistics.mean(dc_scores)

                names = ['Date', 'fk_score', 'dc_score', 'wc', 'text', 'sample1', 'sample2', 'sample3', 'lemma1', 'lemma2', 'lemma3']
                variables = [date, fk_score, dc_score, wc, text, samples[0], samples[1], samples[2], lemmas[0], lemmas[1], lemmas[2]]
                results.append(dict(zip(names, variables)))

                #gf_score = textstat.gunning_fog(text)
                #smog_score = textstat.smog_index(text)
                #cl_score = textstat.coleman_liau_index(text)
                #ls_score = textstat.linsear_write_formula(text)
                    

                    # Append the result as a dictionary

            except Exception as e:
                print(f"Error processing {filename}: {e}")

    return results

# %% [markdown]
# ## FOMC Statements Text Extraction
# - We read the PDFs using the PyPDF2 package
# - Replace newlines with spaces, strip out duplicate spaces. Add spaces between pages
# - Remove the paragraph about voting decision, as we don't want names to interfere with the score
# - Remove starting text (date, title, etc). We identify the first instance of a starting phrase. (The starting phrase has changed over time)
# - Save results in Excel file for later use

# %%
# text extraction and FK score functions
def fomc_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  
                text += page_text + " "  # Add a space between pages
    text = text.replace('\n', ' ').strip() # Replace newlines with space
    text = re.sub(r'\s+', ' ', text).strip()
    #text = re.sub(r'(\S) +(\S)', r'\1\2', text)

    # clean FOMC pdf by removing voting decision details
    truncated_text = text
    if "Voting for" in truncated_text:
        truncated_text = truncated_text.split("Voting for")[0].strip()
    if "In taking the discount rate action" in truncated_text:
        truncated_text = truncated_text.split("In taking the discount rate action")[0].strip()

    starting_phrases = ["Information received", "Recent indicators", "Indicators of economic activity", "The Federal Open Market Committee", "The Federal Reserve", "Economic activity", "Although", "Indicators", "Overall", "received"]

    return_text = truncated_text  # Default if no starting phrase is found
    for phrase in starting_phrases:
        if phrase in truncated_text:
            try:
                return_text = phrase + " " + truncated_text.split(phrase, 1)[1].strip()
                break  
            except IndexError:
                continue 

    return(return_text)

# %%
fomc_statements = pd.DataFrame(process_pdfs('FOMCstatements', fomc_pdf_to_text, 'monetary', 8, 16))

# %%
fomc_statements['Date'] = pd.to_datetime(fomc_statements['Date'])
fomc_statements = fomc_statements.sort_values(by='Date')
fomc_statements = fomc_statements.reset_index(drop=True)
fomc_statements
# Out:
#           Date   fk_score   dc_score   wc  \
# 0   2001-01-03  15.000000  10.220000  192
# 1   2001-03-20  15.200000  11.160000  215
# 2   2001-04-18  14.866667  10.663333  251
# 3   2001-05-15  13.433333  10.723333  229
# 4   2001-06-27  15.400000  10.380000  170
# ..         ...        ...        ...  ...
# 186 2024-06-12  12.500000   9.416667  307
# 187 2024-07-31  11.866667   9.063333  311
# 188 2024-09-18  13.466667  10.100000  293
# 189 2024-11-07  13.166667   9.693333  282
# 190 2024-12-18  12.200000   9.446667  286
#
#                                                   text  \
# 0    The Federal Open Market Committee decided toda...
# 1    The Federal Open Market Committee at its meeti...
# 2    The Federal Open Market Committee decided toda...
# 3    The Federal Open Market Committee at its meeti...
# 4    The Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  Recent indicators suggest that economic activi...
# 187  Recent indicators suggest that economic activi...
# 188  Recent indicators suggest that economic activi...
# 189  Recent indicators suggest that economic activi...
# 190  Recent indicators suggest that economic activi...
#
#                                                sample1  \
# 0    The Federal Open Market Committee decided toda...
# 1    for the federal funds rate by 50 basis points ...
# 2    4 percent. The FOMC has reviewed prospects for...
# 3    percent. In a related action, the Board of Gov...
# 4    The Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  and inflation goals have moved toward better b...
# 187  economic activity has continued to expand at a...
# 188  employment and inflation goals are roughly in ...
# 189  and inflation goals are roughly in balance. Th...
# 190  2 percent objective but remains somewhat eleva...
#
#                                                sample2  \
# 0    The Federal Open Market Committee decided toda...
# 1    its tar get for the federal funds rate by 50 b...
# 2    for the economy in light of the information th...
# 3    The Federal Open Market Committee at its meeti...
# 4    The Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  the risks to achieving its employment and infl...
# 187  economic outlook is uncertain, and the Committ...
# 188  made further progress toward the Committee’s 2...
# 189  Since earlier in the year, labor market condit...
# 190  in the year, labor market conditions have gene...
#
#                                                sample3  \
# 0    The Federal Open Market Committee decided toda...
# 1    to lower its tar get for the federal funds rat...
# 2    action, the Board of Governors approved a 50 b...
# 3    related action, the Board of Governors approve...
# 4    The Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  the Committee’s 2 percent inflation objective ...
# 187  maximum employment and inflation at the rate o...
# 188  greater confidence that inflation is moving su...
# 189  The Committee seeks to achieve maximum employm...
# 190  up but remains low. Inflation has made progres...
#
#                                                 lemma1  \
# 0    the Federal Open Market Committee decide today...
# 1    for the federal fund rate by 50 basis point to...
# 2    4 percent. the FOMC have review prospect for t...
# 3    percent. in a related action, the Board of Gov...
# 4    the Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  and inflation goal have move toward well balan...
# 187  economic activity have continue to expand at a...
# 188  employment and inflation goal be roughly in ba...
# 189  and inflation goal be roughly in balance. the ...
# 190  2 percent objective but remain somewhat elevat...
#
#                                                 lemma2  \
# 0    the Federal Open Market Committee decide today...
# 1    its tar get for the federal fund rate by 50 ba...
# 2    for the economy in light of the information th...
# 3    the Federal Open Market Committee at its meeti...
# 4    the Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  the risk to achieve its employment and inflati...
# 187  economic outlook be uncertain, and the Committ...
# 188  make further progress toward the Committee’s 2...
# 189  since early in the year, labor market conditio...
# 190  in the year, labor market condition have gener...
#
#                                                 lemma3
# 0    the Federal Open Market Committee decide today...
# 1    to lower its tar get for the federal fund rate...
# 2    action, the Board of Governors approve a 50 ba...
# 3    relate action, the Board of Governors approve ...
# 4    the Federal Open Market Committee at its meeti...
# ..                                                 ...
# 186  the Committee’s 2 percent inflation objective ...
# 187  maximum employment and inflation at the rate o...
# 188  great confidence that inflation be move sustai...
# 189  the Committee seek to achieve maximum employme...
# 190  up but remain low. inflation have make progres...
#
# [191 rows x 11 columns]

# %% [markdown]
# ## UK Text Extraction

# %%
def boe_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  # Check if text was extracted
                text += page_text + " "  # Add a newline for separation between pages
    text = text.replace('\n', ' ').strip() # Return the text without trailing newlines

    # clean BoE pdf by removing title page
    truncated_text = text.split("Published on")[1].strip()
    truncated_text = truncated_text.split("Minutes of the Monetary Policy Committee meeting ending on")[0].strip()

    starting_phrases = ["The Bank of England", "MPC"]
    return_text = truncated_text  # Default if no starting phrase is found
    for phrase in starting_phrases:
        if phrase in truncated_text:
            try:
                return_text = phrase + " " + truncated_text.split(phrase, 1)[1].strip()
                break  
            except IndexError:
                continue 

    return(return_text)

# %%
boe_statements = pd.DataFrame(process_pdfs('BoEsummaries', boe_pdf_to_text, 'boe', 3, 11))

# %%
boe_statements
# Out:
#          Date   fk_score   dc_score    wc  \
# 0  2023-05-11  12.033333   8.880000   908
# 1  2018-03-22  11.533333   9.660000   684
# 2  2024-08-01  10.800000   9.680000   523
# 3  2023-09-21  11.666667   9.476667  1050
# 4  2017-06-15  13.833333   9.810000   750
# ..        ...        ...        ...   ...
# 75 2021-06-24  11.566667   9.686667  1042
# 76 2017-08-03  12.666667   9.626667   914
# 77 2017-11-02  13.133333  10.126667   866
# 78 2020-11-05  10.500000   9.373333   900
# 79 2015-12-10  12.200000   9.240000   740
#
#                                                  text  \
# 0   The Bank of England ’ s Monetary Policy Commit...
# 1   The Bank of England ’ s Monetary Policy Commit...
# 2   MPC ) sets monetary policy to meet the 2% infl...
# 3   The Bank of England ’ s Monetary Policy Commit...
# 4   The Bank of England ’ s Monetary Policy Commit...
# ..                                                ...
# 75  The Bank of England ’ s Monetary Policy Commit...
# 76  The Bank of England ’ s Monetary Policy Commit...
# 77  The Bank of England ’ s Monetary Policy Commit...
# 78  The Bank of England ’ s Monetary Policy Commit...
# 79  The Bank of England ’ s Monetary Policy Commit...
#
#                                               sample1  \
# 0   than in the February Report in the near term. ...
# 1   revision, and other indicators of exports and ...
# 2   to meet the 2% inflation target, and in a way ...
# 3   near term, with some potential month-to-month ...
# 4   and the support that monetary policy provides ...
# ..                                                ...
# 75  recruitment dif ficulties for some businesses,...
# 76  in October , as the past depreciation of sterl...
# 77  and consumer confidence has remained resilient...
# 78  expected to pick up in 2021 Q1, as restriction...
# 79  issuance of central bank reserves at £375 bill...
#
#                                               sample2  \
# 0   its meeting ending on 10 May 2023, the MPC vot...
# 1   projected to emerge by early 2020 and build th...
# 2   set of projections for activity and inflation ...
# 3   declined by 0.5% in July and the S&P Global/CI...
# 4   Consumer confidence has remained relatively re...
# ..                                                ...
# 75  purchases at £875 billion and so the total tar...
# 76  the next few years. Attempting to of fset full...
# 77  The ef fects of rising import prices on inflat...
# 78  rate rose to 4.5% in the three months to Augus...
# 79  of further shocks. The MPC set out its most re...
#
#                                               sample3  \
# 0   sharply from April, in part as large rises in ...
# 1   costs will pick up to target- consistent rates...
# 2   , but underlying momentum appears weaker . The...
# 3   over the summer holiday period. Excluding thes...
# 4   quarter , in part reflecting weaker household ...
# ..                                                ...
# 75  target for the stock of these government bond ...
# 76  financed by the issuance of central bank reser...
# 77  a 42-year low and the MPC judges that the leve...
# 78  adjustment, over the first half of next year ,...
# 79  Twelve-month CPI inflation remained at -0.1% i...
#
#                                                lemma1  \
# 0   than in the February Report in the near term. ...
# 1   revision, and other indicator of export and in...
# 2   to meet the 2% inflation target, and in a way ...
# 3   near term, with some potential month-to-month ...
# 4   and the support that monetary policy provide t...
# ..                                                ...
# 75  recruitment dif ficultie for some business, an...
# 76  in October , as the past depreciation of sterl...
# 77  and consumer confidence have remain resilient....
# 78  expect to pick up in 2021 q1, as restriction l...
# 79  issuance of central bank reserve at £375 billi...
#
#                                                lemma2  \
# 0   its meeting end on 10 May 2023, the MPC vote b...
# 1   project to emerge by early 2020 and build ther...
# 2   set of projection for activity and inflation i...
# 3   decline by 0.5% in July and the S&P Global/CIP...
# 4   consumer confidence have remain relatively res...
# ..                                                ...
# 75  purchase at £875 billion and so the total targ...
# 76  the next few year. attempt to of fset fully th...
# 77  the ef fect of rise import price on inflation ...
# 78  rate rise to 4.5% in the three month to August...
# 79  of further shock. the MPC set out its most rec...
#
#                                                lemma3
# 0   sharply from April, in part as large rise in t...
# 1   cost will pick up to target- consistent rate. ...
# 2   , but underlying momentum appear weak . the Co...
# 3   over the summer holiday period. exclude these ...
# 4   quarter , in part reflect weak household spend...
# ..                                                ...
# 75  target for the stock of these government bond ...
# 76  finance by the issuance of central bank reserv...
# 77  a 42-year low and the MPC judge that the level...
# 78  adjustment, over the first half of next year ,...
# 79  twelve-month CPI inflation remain at -0.1% in ...
#
# [80 rows x 11 columns]

# %%
boe_statements['Date'] = pd.to_datetime(boe_statements['Date'])
boe_statements = boe_statements.sort_values(by='Date')
boe_statements = boe_statements.reset_index(drop=True)
boe_statements
# Out:
#          Date   fk_score   dc_score    wc  \
# 0  2015-08-06  12.000000   9.336667  1075
# 1  2015-09-10  13.000000   9.440000   783
# 2  2015-10-08  14.066667  10.466667   836
# 3  2015-11-05  10.700000   9.420000   954
# 4  2015-12-10  12.200000   9.240000   740
# ..        ...        ...        ...   ...
# 75 2024-06-20  10.633333   9.300000   587
# 76 2024-08-01  10.800000   9.680000   523
# 77 2024-09-19  10.366667   9.736667   624
# 78 2024-11-07  12.500000   9.156667   663
# 79 2024-12-19  10.033333   9.790000   503
#
#                                                  text  \
# 0   The Bank of England ’ s Monetary Policy Commit...
# 1   The Bank of England ’ s Monetary Policy Commit...
# 2   The Bank of England ’ s Monetary Policy Commit...
# 3   The Bank of England ’ s Monetary Policy Commit...
# 4   The Bank of England ’ s Monetary Policy Commit...
# ..                                                ...
# 75  The Bank of England ’ s Monetary Policy Commit...
# 76  MPC ) sets monetary policy to meet the 2% infl...
# 77  MPC ) sets monetary policy to meet the 2% infl...
# 78  MPC ) sets monetary policy to meet the 2% infl...
# 79  MPC ) sets monetary policy to meet the 2% infl...
#
#                                               sample1  \
# 0   suggest that medium-term inflation expectation...
# 1   energy , food and import prices waned. In the ...
# 2   at the beginning of 2014. The sharp declines i...
# 3   drag from commodity and other imported goods p...
# 4   issuance of central bank reserves at £375 bill...
# ..                                                ...
# 75  tight by historical standards. The collective ...
# 76  to meet the 2% inflation target, and in a way ...
# 77  member preferred to reduce Bank Rate by 0.25 p...
# 78  withdrawn. The MPC’ s latest projections for a...
# 79  the 2% target both in a timely manner and on a...
#
#                                               sample2  \
# 0   tightening of the labour market is expected, s...
# 1   labour costs in particular . Although pay grow...
# 2   activity and global growth has continued at be...
# 3   growth. The MPC’ s objective is to return infl...
# 4   of further shocks. The MPC set out its most re...
# ..                                                ...
# 75  derived from the ONS Labour Force Survey means...
# 76  set of projections for activity and inflation ...
# 77  Since the MPC’ s previous meeting, global acti...
# 78  by historical standards. Monetary policy has b...
# 79  of 6–3 to maintain Bank Rate at 4.75%. Three m...
#
#                                               sample3  \
# 0   market. Business investment has made a substan...
# 1   best collective judgement is that there remain...
# 2   Growth in the euro area, the United Kingdom’ s...
# 3   is evident in subdued measures of core inflati...
# 4   Twelve-month CPI inflation remained at -0.1% i...
# ..                                                ...
# 75  Report. This strength in part reflected prices...
# 76  , but underlying momentum appears weaker . The...
# 77  continued at a steady pace, although some data...
# 78  Policy Report. In the first case, most of the ...
# 79  Rate at 4.75%. Three members preferred to redu...
#
#                                                lemma1  \
# 0   suggest that medium-term inflation expectation...
# 1   energy , food and import price wane. in the th...
# 2   at the beginning of 2014. the sharp decline in...
# 3   drag from commodity and other import good pric...
# 4   issuance of central bank reserve at £375 billi...
# ..                                                ...
# 75  tight by historical standard. the collective s...
# 76  to meet the 2% inflation target, and in a way ...
# 77  member prefer to reduce Bank rate by 0.25 perc...
# 78  withdraw. the MPC' s late projection for activ...
# 79  the 2% target both in a timely manner and on a...
#
#                                                lemma2  \
# 0   tightening of the labour market be expect, sup...
# 1   labour cost in particular . although pay growt...
# 2   activity and global growth have continue at be...
# 3   growth. the MPC' s objective be to return infl...
# 4   of further shock. the MPC set out its most rec...
# ..                                                ...
# 75  derive from the ONS Labour Force Survey mean t...
# 76  set of projection for activity and inflation i...
# 77  since the MPC' s previous meeting, global acti...
# 78  by historical standard. monetary policy have b...
# 79  of 6–3 to maintain Bank Rate at 4.75%. three m...
#
#                                                lemma3
# 0   market. business investment have make a substa...
# 1   good collective judgement be that there remain...
# 2   growth in the euro area, the United Kingdom' s...
# 3   be evident in subdue measure of core inflation...
# 4   twelve-month CPI inflation remain at -0.1% in ...
# ..                                                ...
# 75  Report. this strength in part reflect price th...
# 76  , but underlying momentum appear weak . the Co...
# 77  continue at a steady pace, although some datum...
# 78  Policy Report. in the first case, most of the ...
# 79  rate at 4.75%. three member prefer to reduce B...
#
# [80 rows x 11 columns]

# %% [markdown]
# ## ECB Text Extraction

# %%
def ecb_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  
                text += page_text + " "  # Add a space between pages
    text = text.replace('\n', ' ').strip() # Replace newlines with space
    text = re.sub(r'\s+', ' ', text).strip()

    statement = text
    qna = text
    # clean FOMC pdf by removing voting decision details
    starting_phrases = ["Ladies and gentlemen", "Good afternoon", "Let me just say", "The Vice-President and I"]

    return_text = text  # Default if no starting phrase is found
    for phrase in starting_phrases:
        if phrase in return_text:
            try:
                return_text = phrase + " " + return_text.split(phrase, 1)[1].strip()
                break  
            except IndexError:
                continue 
    
    ending_phrases = ["disposal for questions", "Question:", "*"]

    for phrase in ending_phrases:
        if phrase in return_text:
            try: 
                split_index = return_text.find(phrase)
                statement = return_text[:split_index].strip() # everything before the phrase
                qna = return_text[split_index:].strip()
                break
            except IndexError:
                continue 

    return statement
#, qna

# %%
ecb_statements = pd.DataFrame(process_pdfs('ECBPress', ecb_pdf_to_text, 'ecb', 8, 16))

# %%
ecb_statements
# Out:
#           Date   fk_score   dc_score    wc  \
# 0   2011-01-13  11.900000   8.980000  1712
# 1   2007-02-08  12.033333   9.526667  1611
# 2   2014-10-02  13.366667  10.270000  1241
# 3   2008-01-10  13.033333   9.910000  1665
# 4   2008-03-06  11.033333   9.520000  1725
# ..         ...        ...        ...   ...
# 237 2019-01-24  16.800000  10.186667   986
# 238 2010-10-07  11.266667   9.153333  1394
# 239 2023-05-04   9.066667   8.930000  1483
# 240 2004-07-01  14.633333  10.883333  1905
# 241 2013-11-07  13.166667   8.526667  1530
#
#                                                   text  \
# 0    Ladies and gentlemen , the Vice-President and ...
# 1    Ladies and gentlemen , let me welcome you to o...
# 2    Ladies and gentlemen , the Vice-President and ...
# 3    Ladies and gentlemen , the Vice-President and ...
# 4    Ladies and gentlemen , the Vice-President and ...
# ..                                                 ...
# 237  Ladies and gentlemen , the Vice-President and ...
# 238  Ladies and gentlemen , the Vice-President and ...
# 239  Good afternoon , the Vice-President and I welc...
# 240  Ladies and gentlemen , the Vice-President and ...
# 241  Ladies and gentlemen , I am very pleased to we...
#
#                                                sample1  \
# 0    Eesti Pank, became a member of the Governing C...
# 1    currently expected wage developments pose subs...
# 2    information on the modalities of our new purch...
# 3    and, consequently, medium and long-term inflat...
# 4    anchoring of medium to longer-term inflation e...
# ..                                                 ...
# 237  summer of 2019, and in any case for as long as...
# 238  that the underlying pace of monetary expansion...
# 239  fiscal policy support for firms and households...
# 240  implementation of this year’s budget and a com...
# 241  maintenance period, which will continue to be ...
#
#                                                sample2  \
# 0    monetary analysis, the annual growth rate of M...
# 1    futures and previous oil price developments, s...
# 2    asset-backed securities (ABSs) in the fourth q...
# 3    2% in the coming months and is likely to moder...
# 4    monitoring wage negotiations in the euro area ...
# ..                                                 ...
# 237  ensure the continued sustained convergence of ...
# 238  the business cycle that was also observed in p...
# 239  supply capacity, especially in the energy sect...
# 240  year’s budget and a comprehensive reform strat...
# 241  money market conditions and their potential im...
#
#                                                sample3  \
# 0    in oil and other commodity prices, protectioni...
# 1    employment growth – continue to improve. Risks...
# 2    time, the recovery is likely to continue to be...
# 3    Council, this is absolutely essential in order...
# 4    in 2008 both domestic and foreign demand are e...
# ..                                                 ...
# 237  euro area. To sum up, a cross-check of the out...
# 238  in September, according to Eurostat’s flash es...
# 239  under the APP as of July 2023. The decisions t...
# 240  the last months, goes in the direction of a co...
# 241  particular, lower food price inflation, a larg...
#
#                                                 lemma1  \
# 0    Eesti Pank, become a member of the Governing C...
# 1    currently expect wage development pose substan...
# 2    information on the modality of our new purchas...
# 3    and, consequently, medium and long-term inflat...
# 4    anchor of medium to long-term inflation expect...
# ..                                                 ...
# 237  summer of 2019, and in any case for as long as...
# 238  that the underlie pace of monetary expansion b...
# 239  fiscal policy support for firm and household h...
# 240  implementation of this year’s budget and a com...
# 241  maintenance period, which will continue to be ...
#
#                                                 lemma2  \
# 0    monetary analysis, the annual growth rate of M...
# 1    future and previous oil price development, sig...
# 2    asset-back security (ABSs) in the fourth quart...
# 3    2% in the come month and be likely to moderate...
# 4    monitor wage negotiation in the euro area with...
# ..                                                 ...
# 237  ensure the continue sustained convergence of i...
# 238  the business cycle that be also observe in pas...
# 239  supply capacity, especially in the energy sect...
# 240  year’s budget and a comprehensive reform strat...
# 241  money market condition and their potential imp...
#
#                                                 lemma3
# 0    in oil and other commodity price, protectionis...
# 1    employment growth – continue to improve. risk ...
# 2    time, the recovery be likely to continue to be...
# 3    Council, this be absolutely essential in order...
# 4    in 2008 both domestic and foreign demand be ex...
# ..                                                 ...
# 237  euro area. to sum up, a cross-check of the out...
# 238  in September, accord to Eurostat’s flash estim...
# 239  under the APP as of July 2023. the decision ta...
# 240  the last month, go in the direction of a confi...
# 241  particular, low food price inflation, a large ...
#
# [242 rows x 11 columns]

# %%
ecb_statements['Date'] = pd.to_datetime(ecb_statements['Date'])
ecb_statements = ecb_statements.sort_values(by='Date')
ecb_statements = ecb_statements.reset_index(drop=True)
ecb_statements
# Out:
#           Date   fk_score  dc_score    wc  \
# 0   2001-02-01  10.633333  9.330000  1344
# 1   2001-03-01  12.333333  9.503333   658
# 2   2001-04-11  10.966667  8.820000  1071
# 3   2001-05-10  12.833333  9.516667  1345
# 4   2001-06-07  12.800000  9.456667  1238
# ..         ...        ...       ...   ...
# 237 2024-04-11   8.466667  8.426667  1372
# 238 2024-06-06  10.633333  9.100000  1595
# 239 2024-07-18   9.133333  8.750000  1420
# 240 2024-09-12  10.166667  9.276667  1663
# 241 2024-10-17   9.166667  9.730000  1453
#
#                                                   text  \
# 0    Ladies and gentlemen , let me welcome you to o...
# 1    Ladies and gentlemen , the Vice-President and ...
# 2    Ladies and gentlemen , the Vice-President and ...
# 3    Ladies and gentlemen , the Vice-President and ...
# 4    Ladies and gentlemen , the Vice-President and ...
# ..                                                 ...
# 237  Good afternoon , the Vice-President and I welc...
# 238  Good afternoon , the Vice-President and I welc...
# 239  Good afternoon , the Vice-President and I welc...
# 240  Good afternoon , the Vice-President and I welc...
# 241  Good afternoon , the Vice-President and I welc...
#
#                                                sample1  \
# 0    direct taxes in 2001. Hence, while downside ri...
# 1    the second half of last year than in the first...
# 2    applies to the extent and duration of the slow...
# 3    4.8% in the period from January to March 2001,...
# 4    might entail a resurfacing of upward risks to ...
# ..                                                 ...
# 237  would help mobilise the massive private invest...
# 238  year. Goods price inflation continued to decre...
# 239  and without delay will help governments bring ...
# 240  that level since our July meeting. Risk assess...
# 241  per cent in August. However, surveys point to ...
#
#                                                sample2  \
# 0    outlook for economic activity. Moreover, infla...
# 1    continuing employment growth and declines in u...
# 2    area. It decided to keep the key ECB interest ...
# 3    decentralised production scheme with pooling. ...
# 4    by domestic demand and will remain broadly in ...
# ..                                                 ...
# 237  with most standing around 2 per cent. Risk ass...
# 238  ensure that inflation returns to our two per c...
# 239  will keep policy rates sufficiently restrictiv...
# 240  will grow by 0.8 per cent in 2024, rising to 1...
# 241  and investment. Exports should contribute to t...
#
#                                                sample3  \
# 0    downside risks to real GDP growth exist, growt...
# 1    of the Governing Council of the ECB. The Gover...
# 2    the rest of the world. While this indicates th...
# 3    the oil price shock. This has been a very posi...
# 4    over 80% of the launch stock. In order to mark...
# ..                                                 ...
# 237  in February to 2.4 per cent in March, accordin...
# 238  and duration of restriction. In particular, ou...
# 239  interest rates, while broader financial condit...
# 240  in the first. Recent survey indicators point t...
# 241  inflation and the strength of monetary policy ...
#
#                                                 lemma1  \
# 0    direct taxis in 2001. hence, while downside ri...
# 1    the second half of last year than in the first...
# 2    apply to the extent and duration of the slowdo...
# 3    4.8% in the period from January to March 2001,...
# 4    might entail a resurfacing of upward risk to p...
# ..                                                 ...
# 237  would help mobilise the massive private invest...
# 238  year. good price inflation continue to decreas...
# 239  and without delay will help government bring d...
# 240  that level since our July meeting. risk assess...
# 241  per cent in August. however, survey point to s...
#
#                                                 lemma2  \
# 0    outlook for economic activity. moreover, infla...
# 1    continue employment growth and decline in unem...
# 2    area. it decide to keep the key ECB interest r...
# 3    decentralise production scheme with pooling. t...
# 4    by domestic demand and will remain broadly in ...
# ..                                                 ...
# 237  with most stand around 2 per cent. risk assess...
# 238  ensure that inflation return to our two per ce...
# 239  will keep policy rate sufficiently restrictive...
# 240  will grow by 0.8 per cent in 2024, rise to 1.3...
# 241  and investment. export should contribute to th...
#
#                                                 lemma3
# 0    downside risk to real GDP growth exist, growth...
# 1    of the Governing Council of the ECB. the Gover...
# 2    the rest of the world. while this indicate tha...
# 3    the oil price shock. this have be a very posit...
# 4    over 80% of the launch stock. in order to mark...
# ..                                                 ...
# 237  in February to 2.4 per cent in March, accord t...
# 238  and duration of restriction. in particular, ou...
# 239  interest rate, while broad financial condition...
# 240  in the first. recent survey indicator point to...
# 241  inflation and the strength of monetary policy ...
#
# [242 rows x 11 columns]

# %%
# edge case: ECB 10-06-2011
with open('ecb1062011.txt', 'r') as file:
    statement = file.read()

#with open('ecbqna1062011.txt', 'r') as file:
    #qna = file.read()

ecb_statements.loc[ecb_statements['Date'] == '2011-10-06', 'text'] = statement
ecb_statements.loc[ecb_statements['Date'] == '2011-10-06', 'wc'] = len(statement.split())
ecb_statements.loc[ecb_statements['Date'] == '2011-10-06', 'fk_score'] = calc_fk(statement)
ecb_statements.loc[ecb_statements['Date'] == '2011-10-06', 'dc_score'] = calc_dc(lemmatize_text(statement))

# %%
pd.set_option('display.max_rows', 10)
ecb_statements
# Out:
#           Date   fk_score  dc_score    wc  \
# 0   2001-02-01  10.633333  9.330000  1344
# 1   2001-03-01  12.333333  9.503333   658
# 2   2001-04-11  10.966667  8.820000  1071
# 3   2001-05-10  12.833333  9.516667  1345
# 4   2001-06-07  12.800000  9.456667  1238
# ..         ...        ...       ...   ...
# 237 2024-04-11   8.466667  8.426667  1372
# 238 2024-06-06  10.633333  9.100000  1595
# 239 2024-07-18   9.133333  8.750000  1420
# 240 2024-09-12  10.166667  9.276667  1663
# 241 2024-10-17   9.166667  9.730000  1453
#
#                                                   text  \
# 0    Ladies and gentlemen , let me welcome you to o...
# 1    Ladies and gentlemen , the Vice-President and ...
# 2    Ladies and gentlemen , the Vice-President and ...
# 3    Ladies and gentlemen , the Vice-President and ...
# 4    Ladies and gentlemen , the Vice-President and ...
# ..                                                 ...
# 237  Good afternoon , the Vice-President and I welc...
# 238  Good afternoon , the Vice-President and I welc...
# 239  Good afternoon , the Vice-President and I welc...
# 240  Good afternoon , the Vice-President and I welc...
# 241  Good afternoon , the Vice-President and I welc...
#
#                                                sample1  \
# 0    direct taxes in 2001. Hence, while downside ri...
# 1    the second half of last year than in the first...
# 2    applies to the extent and duration of the slow...
# 3    4.8% in the period from January to March 2001,...
# 4    might entail a resurfacing of upward risks to ...
# ..                                                 ...
# 237  would help mobilise the massive private invest...
# 238  year. Goods price inflation continued to decre...
# 239  and without delay will help governments bring ...
# 240  that level since our July meeting. Risk assess...
# 241  per cent in August. However, surveys point to ...
#
#                                                sample2  \
# 0    outlook for economic activity. Moreover, infla...
# 1    continuing employment growth and declines in u...
# 2    area. It decided to keep the key ECB interest ...
# 3    decentralised production scheme with pooling. ...
# 4    by domestic demand and will remain broadly in ...
# ..                                                 ...
# 237  with most standing around 2 per cent. Risk ass...
# 238  ensure that inflation returns to our two per c...
# 239  will keep policy rates sufficiently restrictiv...
# 240  will grow by 0.8 per cent in 2024, rising to 1...
# 241  and investment. Exports should contribute to t...
#
#                                                sample3  \
# 0    downside risks to real GDP growth exist, growt...
# 1    of the Governing Council of the ECB. The Gover...
# 2    the rest of the world. While this indicates th...
# 3    the oil price shock. This has been a very posi...
# 4    over 80% of the launch stock. In order to mark...
# ..                                                 ...
# 237  in February to 2.4 per cent in March, accordin...
# 238  and duration of restriction. In particular, ou...
# 239  interest rates, while broader financial condit...
# 240  in the first. Recent survey indicators point t...
# 241  inflation and the strength of monetary policy ...
#
#                                                 lemma1  \
# 0    direct taxis in 2001. hence, while downside ri...
# 1    the second half of last year than in the first...
# 2    apply to the extent and duration of the slowdo...
# 3    4.8% in the period from January to March 2001,...
# 4    might entail a resurfacing of upward risk to p...
# ..                                                 ...
# 237  would help mobilise the massive private invest...
# 238  year. good price inflation continue to decreas...
# 239  and without delay will help government bring d...
# 240  that level since our July meeting. risk assess...
# 241  per cent in August. however, survey point to s...
#
#                                                 lemma2  \
# 0    outlook for economic activity. moreover, infla...
# 1    continue employment growth and decline in unem...
# 2    area. it decide to keep the key ECB interest r...
# 3    decentralise production scheme with pooling. t...
# 4    by domestic demand and will remain broadly in ...
# ..                                                 ...
# 237  with most stand around 2 per cent. risk assess...
# 238  ensure that inflation return to our two per ce...
# 239  will keep policy rate sufficiently restrictive...
# 240  will grow by 0.8 per cent in 2024, rise to 1.3...
# 241  and investment. export should contribute to th...
#
#                                                 lemma3
# 0    downside risk to real GDP growth exist, growth...
# 1    of the Governing Council of the ECB. the Gover...
# 2    the rest of the world. while this indicate tha...
# 3    the oil price shock. this have be a very posit...
# 4    over 80% of the launch stock. in order to mark...
# ..                                                 ...
# 237  in February to 2.4 per cent in March, accord t...
# 238  and duration of restriction. in particular, ou...
# 239  interest rate, while broad financial condition...
# 240  in the first. recent survey indicator point to...
# 241  inflation and the strength of monetary policy ...
#
# [242 rows x 11 columns]

# %% [markdown]
# ## Process Minutes

# %%
# process pdfs, calculate their FK scores
def process_min_pdfs(folder_path, text_function, name, start, end):
    results = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdf') and name in filename:
            # Extract date from the filename
            date_str = filename[start:end]  
            date = datetime.strptime(date_str, '%m%d%Y')

            # Extract text from the PDF
            pdf_path = os.path.join(folder_path, filename)
            try:
                text = text_function(pdf_path)

                # Calculate key statistics
                fk_score = calc_fk(text)
                #lemmas = lemmatize_text(text)
                #dc_score = calc_dc(lemmas)
                wc = len(text.split())
                results.append({'Date': date, 'fk_score': fk_score, 'wc': wc, 'text': text})

            except Exception as e:
                print(f"Error processing {filename}: {e}")

    return results

# %% [markdown]
# ### FOMC Minutes

# %%
def fomcmin_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  
                text += page_text + " "  
    text = text.replace('\n', ' ').strip() 
    text = re.sub(r'\s+', ' ', text).strip()

    # Find all occurrences of "Minutes of the Monetary Policy Committee"
    split_text = re.split(r"vote", text, flags=re.IGNORECASE, maxsplit=1)

    if len(split_text) > 1:
        text = split_text[1]
    return text

# %%
fomc_min = pd.DataFrame(process_pdfs('FOMCminutes', fomcmin_pdf_to_text, 'min', 3, 11))

# %%
fomc_min['Date'] = pd.to_datetime(fomc_min['Date'])
fomc_min = fomc_min.sort_values(by='Date')
fomc_min = fomc_min.reset_index(drop=True)
fomc_min
# Out:
#           Date   fk_score   dc_score    wc  \
# 0   2001-01-01  16.066667  10.373333  8677
# 1   2001-03-01  14.266667   9.680000  4650
# 2   2001-05-01  15.166667  10.033333  4781
# 3   2001-06-01  16.000000  10.673333  4699
# 4   2001-08-01  14.366667  10.646667  4600
# ..         ...        ...        ...   ...
# 186 2024-06-01  14.066667   9.663333  5190
# 187 2024-07-01  16.866667  10.560000  6456
# 188 2024-09-01  13.966667   9.770000  6083
# 189 2024-11-01  12.000000   9.513333  6497
# 190 2024-12-01   8.700000   9.356667  6124
#
#                                                   text  \
# 0    , the following ofﬁcers of the Federal Open Ma...
# 1    , the minutes of the meeting of the Federal Op...
# 2    , the minutes of the meeting of the Federal Op...
# 3    , the minutes of the meeting of the Federal Op...
# 4    , the minutes of the meeting of the Federal Op...
# ..                                                 ...
# 186  , the Committee ratified the Desk’s domestic t...
# 187  , the Committee ratified the Desk ’s domestic ...
# 188  , the Committee ratified the Desk’s domestic t...
# 189  , the Committee ratified the Desk ’s domestic ...
# 190  , the Committee ratified the Desk’s domestic t...
#
#                                                sample1  \
# 0    form of cable transfers through spot or forwar...
# 1    lower interest rates, and relatively robust ex...
# 2    before the ef fects of countervailing actions ...
# 3    the members believed that the risks to the exp...
# 4    reserve markets consistent with a decrease of ...
# ..                                                 ...
# 186  asset prices. Many participants observed that,...
# 187  judged that it was appropriate to continue the...
# 188  5 ¼ percent in light of core inflation remaini...
# 189  Survey on Bank Lending Practices (SLOOS), bank...
# 190  but the unemployment rate remained low. Consum...
#
#                                                sample2  \
# 0    pool or the permanent portfolio, with the safe...
# 1    apparently was not as far along. In the absenc...
# 2    Bank of New York. The information reviewed at ...
# 3    in May , and there were signs that weakness in...
# 4    the outlook for reopening the stock exchanges....
# ..                                                 ...
# 186  rose in April and May to the highest levels si...
# 187  their Di strict contacts reported that they we...
# 188  this FOMC meeting, participants submitted thei...
# 189  domestic product (GDP) had expanded solidly so...
# 190  Bowman, Lisa D. Cook, Mary C. Daly, Philip N. ...
#
#                                                sample3  \
# 0    continued to read as follows: GUIDELINES FOR T...
# 1    Confer ences On April 1 1, 2001, the Committee...
# 2    an end, adding to the upward momentum of econo...
# 3    the second quarter , reﬂecting the ef fects of...
# 4    objectives, the Committee in the immediate fut...
# ..                                                 ...
# 186  stayed slightly above pre- pandemic levels. In...
# 187  ucture, and, potentially, the overall economy....
# 188  to housing services prices, some participants ...
# 189  of geopolitical tensions or a sizable as set p...
# 190  the third quarter, notably in the euro area an...
#
#                                                 lemma1  \
# 0    form of cable transfer through spot or forward...
# 1    low interest rate, and relatively robust expan...
# 2    before the ef fect of countervail action by th...
# 3    the member believe that the risk to the expans...
# 4    reserve market consistent with a decrease of 2...
# ..                                                 ...
# 186  asset price. many participant observe that, in...
# 187  judge that it be appropriate to continue the p...
# 188  5 ¼ percent in light of core inflation remain ...
# 189  survey on Bank Lending Practices (SLOOS), bank...
# 190  but the unemployment rate remain low. consumer...
#
#                                                 lemma2  \
# 0    pool or the permanent portfolio, with the safe...
# 1    apparently be not as far along. in the absence...
# 2    Bank of New York. the information review at th...
# 3    in May , and there be sign that weakness in em...
# 4    the outlook for reopen the stock exchange. whi...
# ..                                                 ...
# 186  rise in April and May to the high level since ...
# 187  their Di strict contact report that they be ac...
# 188  this fomc meeting, participant submit their pr...
# 189  domestic product (GDP) have expand solidly so ...
# 190  Bowman, Lisa D. Cook, Mary C. Daly, Philip N. ...
#
#                                                 lemma3
# 0    continue to read as follow: GUIDELINES for the...
# 1    confer ence on April 1 1, 2001, the Committee ...
# 2    an end, add to the upward momentum of economic...
# 3    the second quarter , reﬂecte the ef fect of lo...
# 4    objective, the Committee in the immediate futu...
# ..                                                 ...
# 186  stay slightly above pre- pandemic level. in th...
# 187  ucture, and, potentially, the overall economy....
# 188  to housing service price, some participant sug...
# 189  of geopolitical tension or a sizable as set pr...
# 190  the third quarter, notably in the euro area an...
#
# [191 rows x 11 columns]

# %% [markdown]
# ### BoE Minutes

# %%
def boemin_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  
                text += page_text + " "  
    text = text.replace('\n', ' ').strip() 
    text = re.sub(r'\s+', ' ', text).strip()

    # Check if "Minutes of Monetary" is in the text
    has_mom = re.search(r"Minutes of Monetary", text, re.IGNORECASE) is not None

    # Find all occurrences of "Minutes of the Monetary Policy Committee"
    split_text = re.split(r"minutes of the monetary", text, flags=re.IGNORECASE)


    # If "Minutes of Monetary" is found, take text after the second MPC occurrence
    if has_mom and len(split_text) > 2:
        text = split_text[2]
    # Otherwise, take text after the third MPC occurrence
    elif len(split_text) > 4:
        text = split_text[3]

    return text

# %%
def boemin_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  # Check if text was extracted
                text += page_text + " "  # Add a newline for separation between pages
    text = text.replace('\n', ' ').strip() # Return the text without trailing newlines

    phrase = "Before turning to"
    return_text = text

    if phrase in text:
        return_text = phrase + " " + text.split(phrase, 1)[1].strip()

    return(return_text)

# %%
boe_min = pd.DataFrame(process_pdfs('BOEminutes', boemin_pdf_to_text, 'mpc', 3, 11))

# %%
boe_min['Date'] = pd.to_datetime(boe_min['Date'])
boe_min = boe_min.sort_values(by='Date')
boe_min = boe_min.reset_index(drop=True)
boe_min
# Out:
#           Date   fk_score  dc_score    wc  \
# 0   2001-01-10   8.333333  8.650000  8093
# 1   2001-02-08   6.900000  8.866667  7932
# 2   2001-03-07  12.366667  8.783333  8571
# 3   2001-04-04  11.900000  9.153333  9230
# 4   2001-05-09  10.833333  9.343333  9076
# ..         ...        ...       ...   ...
# 250 2024-06-20  11.533333  9.426667  5016
# 251 2024-08-01  10.900000  9.476667  2213
# 252 2024-09-19  10.966667  8.956667  4218
# 253 2024-11-07  10.000000  9.286667  1750
# 254 2024-12-19  10.133333  9.450000  3783
#
#                                                   text  \
# 0    Before turning to its immediate policy decisio...
# 1    Before turning to its immediate policy decisio...
# 2    Before turning to its immediate policy decisio...
# 3    Before turning to its immediate policy decisio...
# 4    Before turning to its immediate policy decisio...
# ..                                                 ...
# 250  Before turning to its immediate policy decisio...
# 251  Before turning to its immediate policy decisio...
# 252  Before turning to its immediate policy decisio...
# 253  Before turning to its immediate policy decisio...
# 254  Before turning to its immediate policy decisio...
#
#                                                sample1  \
# 0    from 3.6% in October to 3.7% in November. The ...
# 1    The Bank’s twelve-month AEI-weighted mean meas...
# 2    offered outside the M4 sector, substantial hou...
# 3    credit aggregates continued to grow robustly, ...
# 4    notes and coin growth in recent months. A12 Th...
# ..                                                 ...
# 250  expected CPI inflation to increase slightly in...
# 251  import prices and inflation, all else equal , ...
# 252  set an amount for the reduction in the stock o...
# 253  back significantly since mid -2023, but it had...
# 254  while the labour market in the United States h...
#
#                                                sample2  \
# 0    target since April 1999 and recent development...
# 1    made by UK firms in January had been higher th...
# 2    be reflected in lower profitability and the va...
# 3    implied by short sterling futures contracts ha...
# 4    was too soon to form a view on the overall eco...
# ..                                                 ...
# 250  volatile components, rents and foreign holiday...
# 251  than earlier in the year . 20. Following weakn...
# 252  meeting ending on 18 September, the FOMC was e...
# 253  as expected, but material downside news to wag...
# 254  mortgages were refinanced on to higher rates. ...
#
#                                                sample3  \
# 0    percentage points). A26 Export growth in Q3 ha...
# 1    (PNFCs’) M4 and M4 lending growth in December,...
# 2    to the Pre-Budget Report (PBR) forecast, extra...
# 3    resilience of the sterling exchange rate. For ...
# 4    disease. It was likely that strong consumption...
# ..                                                 ...
# 250  reported a pickup in consumer demand in 2024 Q...
# 251  in 2024 Q1, with that strength appearing to ha...
# 252  intelligence indicated that pay settlements ov...
# 253  was unlikely to intensify over the coming year...
# 254  of median one- year ahead inflation expectatio...
#
#                                                 lemma1  \
# 0    from 3.6% in October to 3.7% in November. the ...
# 1    the Bank’s twelve-month AEI-weighted mean meas...
# 2    offer outside the M4 sector, substantial house...
# 3    credit aggregate continue to grow robustly, su...
# 4    note and coin growth in recent month. A12 the ...
# ..                                                 ...
# 250  expect CPI inflation to increase slightly in t...
# 251  import price and inflation, all else equal , b...
# 252  set an amount for the reduction in the stock o...
# 253  back significantly since mid -2023, but it hav...
# 254  while the labour market in the United States h...
#
#                                                 lemma2  \
# 0    target since April 1999 and recent development...
# 1    make by UK firm in January have be high than i...
# 2    be reflect in low profitability and the value ...
# 3    imply by short sterling future contract have a...
# 4    be too soon to form a view on the overall econ...
# ..                                                 ...
# 250  volatile component, rent and foreign holiday, ...
# 251  than early in the year . 20. follow weakness i...
# 252  meeting end on 18 September, the FOMC be expec...
# 253  as expect, but material downside news to wage ...
# 254  mortgage be refinance on to high rate. as note...
#
#                                                 lemma3
# 0    percentage point). a26 export growth in Q3 hav...
# 1    (pnfc') M4 and m4 lend growth in December, dow...
# 2    to the Pre-Budget Report (PBR) forecast, extra...
# 3    resilience of the sterling exchange rate. for ...
# 4    disease. it be likely that strong consumption ...
# ..                                                 ...
# 250  report a pickup in consumer demand in 2024 q2 ...
# 251  in 2024 Q1, with that strength appear to have ...
# 252  intelligence indicate that pay settlement over...
# 253  be unlikely to intensify over the come year . ...
# 254  of median one- year ahead inflation expectatio...
#
# [255 rows x 11 columns]

# %% [markdown]
# ### ECB Minutes

# %%
def ecbmin_pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:  
                text += page_text + " "  
    text = text.replace('\n', ' ').strip() 
    text = re.sub(r'\s+', ' ', text).strip()

    # Find all occurrences of "Minutes of the Monetary Policy Committee"
    split_text = re.split(r"financial market developments", text, flags=re.IGNORECASE, maxsplit=1)

    if len(split_text) > 1:
        text = split_text[1]

    #split_text = re.split(r"press conference", text, flags=re.IGNORECASE)

    #if len(split_text) > 1:
    #    text = split_text[0]
    return text

# %%
ecb_min = pd.DataFrame(process_pdfs('ECBminutes', ecbmin_pdf_to_text, 'ecb', 3, 11))

# %%
ecb_min['Date'] = pd.to_datetime(ecb_min['Date'])
ecb_min = ecb_min.sort_values(by='Date')
ecb_min = ecb_min.reset_index(drop=True)
ecb_min
# Out:
#          Date   fk_score   dc_score     wc  \
# 0  2015-01-22  12.500000   9.106667   9603
# 1  2015-04-02  12.966667   9.796667   7375
# 2  2015-05-21  12.733333   9.606667   6834
# 3  2015-07-02  13.933333  10.350000   6534
# 4  2015-08-13  11.033333  10.190000   7350
# ..        ...        ...        ...    ...
# 77 2024-07-04  13.700000   9.700000  10044
# 78 2024-08-22  12.766667   8.796667   7221
# 79 2024-10-10  12.266667   9.223333   9853
# 80 2024-11-14  14.400000   9.800000   8524
# 81 2025-01-16   9.366667   9.153333  10579
#
#                                                  text  \
# 0    Mr Cœuré reviewed recent financial market dev...
# 1    Mr Cœuré reviewed recent financial market dev...
# 2    Mr Cœuré reviewed recent financial market dev...
# 3    Mr Cœuré reviewed recent financial market dev...
# 4    Mr Cœuré reviewed recent financial market dev...
# ..                                                ...
# 77   Ms Schnabel noted that since the Governing Co...
# 78   Ms Schnabel noted that since the Governing Co...
# 79   Ms Schnabel noted that since the Governing Co...
# 80   Ms Schnabel noted that since the Governing Co...
# 81   Ms Schnabel noted that, since the Governing C...
#
#                                               sample1  \
# 0   indicators currently stood at, or close to, th...
# 1   on an annual basis. The unemployment rate had ...
# 2   line with its usual seasonal pattern and, base...
# 3   significantly exacerbating the rise in bond yi...
# 4   developments in the euro area. Following a slo...
# ..                                                ...
# 77  as a whole was likely to remain in the first q...
# 78  outlook, caution was expressed that this decli...
# 79  the main refinancing operations. As announced ...
# 80  PMI for services activity declining to 51.4 in...
# 81  better understand the likely response of China...
#
#                                               sample2  \
# 0   evidence that a turning point had occurred in ...
# 1   of the upward revisions. In this respect, the ...
# 2   area Mr Praet reviewed the global environment ...
# 3   within MFI liabilities towards short-term inst...
# 4   facility would remain unchanged at 0.05%, 0.30...
# ..                                                ...
# 77  of each year. The fourth quarter was less affe...
# 78  around the target in 2026. It was also importa...
# 79  had supported the baseline scenario, there wer...
# 80  an annual rate of 0.8% in August, on the back ...
# 81  still contracting and growth in services was s...
#
#                                               sample3  \
# 0   the euro area, together with the likelihood of...
# 1   in the view of market participants, the euro a...
# 2   were expected to dampen its pace. Several comm...
# 3   Mr Jazbec Mr Knot Ms Lautenschläger Mr Liikane...
# 4   at around €95 billion at the end of June, with...
# ..                                                ...
# 77  while the evolution of cost dynamics (includin...
# 78  they had been fluctuating to some extent since...
# 79  productivity growth remained low and profits a...
# 80  adjustments. At the same time, labour cost pre...
# 81  fluctuate around its current levels in the nea...
#
#                                                lemma1  \
# 0   indicator currently stand at, or close to, the...
# 1   on an annual basis. the unemployment rate have...
# 2   line with its usual seasonal pattern and, base...
# 3   significantly exacerbate the rise in bond yiel...
# 4   development in the euro area. follow a slowdow...
# ..                                                ...
# 77  as a whole be likely to remain in the first qu...
# 78  outlook, caution be express that this decline ...
# 79  the main refinance operation. as announce in M...
# 80  pmi for service activity decline to 51.4 in Se...
# 81  well understand the likely response of China t...
#
#                                                lemma2  \
# 0   evidence that a turning point have occur in th...
# 1   of the upward revision. in this respect, the i...
# 2   area Mr Praet review the global environment an...
# 3   within MFI liability towards short-term instru...
# 4   facility would remain unchanged at 0.05%, 0.30...
# ..                                                ...
# 77  of each year. the fourth quarter be less affec...
# 78  around the target in 2026. it be also importan...
# 79  have support the baseline scenario, there be u...
# 80  an annual rate of 0.8% in August, on the back ...
# 81  still contract and growth in service be slow. ...
#
#                                                lemma3
# 0   the euro area, together with the likelihood of...
# 1   in the view of market participant, the euro ar...
# 2   be expect to dampen its pace. several comment ...
# 3   Mr Jazbec Mr Knot Ms Lautenschläger Mr Liikane...
# 4   at around €95 billion at the end of June, with...
# ..                                                ...
# 77  while the evolution of cost dynamic (include t...
# 78  they have be fluctuate to some extent since th...
# 79  productivity growth remain low and profit abso...
# 80  adjustment. at the same time, labour cost pres...
# 81  fluctuate around its current level in the near...
#
# [82 rows x 11 columns]

# %%
names = ["fomc", "boe", "ecb", "fomcmin", "boemin", "ecbmin"]

dataframes = [fomc_statements, boe_statements, ecb_statements, fomc_min, boe_min, ecb_min]

with pd.ExcelWriter('text_scores.xlsx', engine='openpyxl') as writer:
    for i, frame in enumerate(dataframes):
        frame.to_excel(writer, sheet_name=names[i], index=False)
